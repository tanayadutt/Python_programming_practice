# %% [markdown]
# # Data Type Assignment

# %% [markdown]
# #### 1. Sales Data Type Identification ####

# %%
sales = "12500"
returns = 320
rating = 4.6
is_active = True

sales = int(sales)

print(type(sales))
print(type(returns))
print(type(rating))
print(type(is_active))


processed_orders = sales - returns

print(processed_orders)
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# 12180

# %% [markdown]
# #### 2. Customer Age Segmentation

# %%
ages = [22.0, 34.7, 45.2, 29.9]

ages_int = [int(age) for age in ages]

age_new = [age >= 30 for age in ages_int]

print(ages_int)
# Out:
# [22, 34, 45, 29]

# %% [markdown]
#  #### 3. Product Code String Analysis

# %%
code = "FLP-ELC-45987"
 
new = code.split("-")

new
# returned the tring into a list form after splitting
# Out:
# ['FLP', 'ELC', '45987']

# %%
extract = new[1]
extract
# Out:
# 'ELC'

# %%
productid = int(new[2])
productid
# Out:
# 45987

# %% [markdown]
# #### 4. Revenue Precision Handling

# %%
revenue = 15342.78965


rounded = round(revenue,2)

rounded_str = str(rounded)

print(rounded)
print(rounded_str)
# Out:
# 15342.79
# 15342.79

# %% [markdown]
# #### 5. User Review Cleaning

# %%
review = "   food was AMAZING!!!   "

#Task: Remove extra spaces
#Convert to lowercase
#Replace multiple exclamation marks with a single !


review_cleaned = review.strip().lower()
review_cleaned = review_cleaned.replace('!!!','!')
print(review_cleaned)
# Out:
# food was amazing!

# %% [markdown]
# #### 6. Boolean Logic in Campaign Targeting

# %%
clicked_ad = True
purchase_made = False

retarget = clicked_ad and not purchase_made
print(retarget)
# Out:
# True

# %% [markdown]
# #### 7. Name Initial Extraction

# %%
name = "Tanaya Dutt"

split = name.split()
split
# Out:
# ['Tanaya', 'Dutt']

# %%
initials = split[0][0] + "." + split[1][0]
initials
# Out:
# 'T.D'

# %% [markdown]
# #### 8. Missing Value Identification

# %%
salary = None

if salary == None:
    salary = 0
    
print(salary)
# Out:
# 0

# %% [markdown]
# #### 9. Log Message Slicing

# %%
log = "ERROR_2026_SERVER_DOWN"

log[11:]
# Out:
# 'SERVER_DOWN'

# %% [markdown]
# #### 10. Numeric String Validation

# %%
txn_id = "458963"

txn_new = int(txn_id)
txn_new
type(txn_new)
# Out:
# int

# %% [markdown]
# #### 11. Percentage Calculation

# %%
completed = 35
total = 50

percentage = (completed/total) * 100
percentage
# Out:
# 70.0

# %% [markdown]
# #### 12. Username Normalization

# %%
username = "  Tanaya_dutt2002  "

trim_username = username.strip()

# %%
trim_username
# Out:
# 'Tanaya_dutt2002'

# %%
lower_username = trim_username.lower()
lower_username
# Out:
# 'tanaya_dutt2002'

# %% [markdown]
# #### 13. Flag High Value Customer

# %%
spend = 135000
high_value = spend >130000
high_value
# Out:
# True

# %% [markdown]
# #### 14. Sentence Word Count

# %%
sentence = "data analytics drives business decisions"

count = len(sentence.split())
count
# Out:
# 5

# %% [markdown]
# #### 15. Mixed Type Data Cleaning

# %%
data = ["4500", 3200, "1800", 2750]

data_int = [int(y) for y in data]
data_int
# Out:
# [4500, 3200, 1800, 2750]

# %% [markdown]
# #### 16. Password Strength Flag

# %%
password = "Data@123"

if len(password)>=8:
    print('Strong Password')
# Out:
# Strong Password

# %% [markdown]
# #### 17. ID Type Consistency Check

# %%
ids = ["101", "102", "103"]

ids = list(map(int, ids))

print(ids)
# Out:
# [101, 102, 103]

# %% [markdown]
# #### 18. Case Conversion for Reporting

# %%
department = "data analytics"

department.title()
# Out:
# 'Data Analytics'

# %% [markdown]
# #### 19. Boolean From Numeric

# %%
flag = 1

bool(flag)
# Out:
# True

# %% [markdown]
# #### 20. Email Domain Extraction

# %%
email = "jay.amin@gmail.com"

domain = email.split("@")

# %%
domain
# Out:
# ['jay.amin', 'gmail.com']

# %%
domain[1]
# Out:
# 'gmail.com'
