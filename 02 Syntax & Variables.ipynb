# %% [markdown]
# ### Syntax & Variables ###

# %% [markdown]
# #### Task 1: Python Syntax Validation (Indentation Control) ####

# %%
salary = 55000
if salary > 50000:
    bonus = salary * 0.10
    if salary > 80000:
        bonus = salary *0.20
print("Bonus:", bonus)
print('Bonus Calculation Completed')
# Out:
# Bonus: 5500.0
# Bonus Calculation Completed

# %% [markdown]
# #### Task 2: Variable Identification & Data Types ####

# %%
order_id = 1000
customer_name = "Tanaya"
order_amount = 13000
is_paid = True
delivery_date = "1/20/2026"

print(type(order_id))
print(type(customer_name))
print(type(order_amount))
print(type(is_paid))
print(type(delivery_date))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# #### Task 3: Business Rule Using Boolean & None####

# %%
purchase_amount = 2000
is_premium_customer = True
discount = None

#Apply
#10% discount if premium
#No discount otherwise

if is_premium_customer == True:
    discount = purchase_amount * 0.10
  
    
print("Final Amount:" , discount + purchase_amount)
# Out:
# Final Amount: 2200.0

# %% [markdown]
# #### Task 4: Variable Naming & Refactoring Exercise ####

# %%
# Given Code
#a = 50000
#b = 0.18
#c = a * b

salary = 50000
tax_rate = 0.118
tax_amount = salary * tax_rate

print(salary)
print(tax_rate)
print(tax_amount)
# Out:
# 50000
# 0.118
# 5900.0

# %% [markdown]
# #### Task 5: Memory Reference Check Using id() ####

# %%
a = 20
b = a

print(id(a),id(b))

b = 60

print(id(a),id(b))

#got same id first, then different
# Out:
# 140730696242568 140730696242568
# 140730696242568 140730696243848

# %% [markdown]
# #### Task 6: Boolean Evaluation from Data

# %%
print(bool(0))
print(bool(1))
print(bool(""))
print(bool("Data"))
print(bool(None))
print(bool([]))
# Out:
# False
# True
# False
# True
# False
# False

# %% [markdown]
# #### Task 7: Keyword Safety Check

# %%
for = 10
if = 5
None = "value"
# Out:
#   Cell In[22], line 1
#     for = 10
#         ^
# SyntaxError: invalid syntax

# %%
for_value = 10
if_condition = 5
none_value = "value"

# %% [markdown]
# #### Task 8: Mini Data Scenario – Customer Eligibility ####

# %%
customer_age = 34
has_membership = False
is_verified = True

if customer_age >=18:
    if has_membership == True:
        if is_verified == True:
            print('Eligible for membership')
    else :
         print('Not Eligible')
# Out:
# Not Eligible

# %% [markdown]
# #### Task 9: Debugging & Syntax Awareness ####

# %%
#Given Code
#is_active = "True"
#if is_active:
 #   print("Active User")
    
#The given code has a boolean value with apostrophe thus it is not recognized as a boolean

is_active = True
if is_active:
    print("Active User")
# Out:
# Active User

# %% [markdown]
# #### Task 10: Consolidated Practice Script ####

# %% [markdown]
# #### Bonus Eligibility ####

# %%
employee_name = input("Enter Name : ") 
employee_age = input ("Enter age : ")
time_spent_years = input (" How much time have you worked here?")
attendance = input("Attendance : ")

if int(time_spent_years) > 3:
    if int(attendance) >= 90:
        print("Eligible for Bonus")
else:
    print("Not Eligible for Bonus")
# Out:
# Enter Name : Tanaya Dutt
# Enter age : 23
#  How much time have you worked here?4
# Attendance : 98
# Eligible for Bonus
